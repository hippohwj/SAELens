# %% [markdown]
# # Training a basic SAE with SAELens
#
# This tutorial demonstrates training a simple, relatively small Sparse Autoencoder, specifically on the tiny-stories-1L-21M model.
#
# As the SAELens library is under active development, please open an issue if this tutorial is stale [here](https://github.com/jbloomAus/SAELens).

# %% [markdown]
# ## Setup

# %%
try:
    # import google.colab # type: ignore
    # from google.colab import output
    # %pip install sae-lens transformer-lens circuitsvis
except:
    from IPython import get_ipython  # type: ignore

    ipython = get_ipython()
    assert ipython is not None
    ipython.run_line_magic("load_ext", "autoreload")
    ipython.run_line_magic("autoreload", "2")
# Out:
# Requirement already satisfied: sae-lens in /usr/local/lib/python3.12/dist-packages (6.12.1)
# Requirement already satisfied: transformer-lens in /usr/local/lib/python3.12/dist-packages (2.16.1)
# Requirement already satisfied: circuitsvis in /usr/local/lib/python3.12/dist-packages (1.43.3)
# Requirement already satisfied: babe<0.0.8,>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from sae-lens) (0.0.7)
# Requirement already satisfied: datasets>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from sae-lens) (4.0.0)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.12/dist-packages (from sae-lens) (3.9.1)
# Requirement already satisfied: plotly>=5.19.0 in /usr/local/lib/python3.12/dist-packages (from sae-lens) (5.24.1)
# Requirement already satisfied: plotly-express>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from sae-lens) (0.4.1)
# Requirement already satisfied: python-dotenv>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from sae-lens) (1.1.1)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.1 in /usr/local/lib/python3.12/dist-packages (from sae-lens) (6.0.2)
# Requirement already satisfied: safetensors<1.0.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from sae-lens) (0.6.2)
# Requirement already satisfied: simple-parsing<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from sae-lens) (0.1.7)
# Requirement already satisfied: tenacity>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from sae-lens) (9.1.2)
# Requirement already satisfied: transformers<5.0.0,>=4.38.1 in /usr/local/lib/python3.12/dist-packages (from sae-lens) (4.56.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from sae-lens) (4.15.0)
# Requirement already satisfied: accelerate>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (1.10.1)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (0.0.3)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (0.8.1)
# Requirement already satisfied: fancy-einsum>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (0.3.2)
# Requirement already satisfied: numpy<2,>=1.26 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (2.2.2)
# Requirement already satisfied: rich>=12.6.0 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (13.9.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (0.2.1)
# Requirement already satisfied: torch>=2.6 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (2.8.0+cu126)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (4.67.1)
# Requirement already satisfied: transformers-stream-generator<0.0.6,>=0.0.5 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (0.0.5)
# Requirement already satisfied: typeguard<5.0,>=4.2 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (4.4.4)
# Requirement already satisfied: wandb>=0.13.5 in /usr/local/lib/python3.12/dist-packages (from transformer-lens) (0.21.3)
# Requirement already satisfied: importlib-metadata>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from circuitsvis) (8.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.23.0->transformer-lens) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.23.0->transformer-lens) (5.9.5)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.23.0->transformer-lens) (0.34.4)
# Requirement already satisfied: py2store in /usr/local/lib/python3.12/dist-packages (from babe<0.0.8,>=0.0.7->sae-lens) (0.1.21)
# Requirement already satisfied: graze in /usr/local/lib/python3.12/dist-packages (from babe<0.0.8,>=0.0.7->sae-lens) (0.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=3.1.0->sae-lens) (3.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.1.0->sae-lens) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.1.0->sae-lens) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.1.0->sae-lens) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=3.1.0->sae-lens) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.1.0->sae-lens) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (2025.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=5.1.0->circuitsvis) (3.23.0)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from jaxtyping>=0.2.11->transformer-lens) (0.1.7)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.8.1->sae-lens) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.8.1->sae-lens) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.8.1->sae-lens) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->transformer-lens) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->transformer-lens) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->transformer-lens) (2025.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from plotly-express>=0.4.1->sae-lens) (0.14.5)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.12/dist-packages (from plotly-express>=0.4.1->sae-lens) (1.16.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.12/dist-packages (from plotly-express>=0.4.1->sae-lens) (1.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.6.0->transformer-lens) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.6.0->transformer-lens) (2.19.2)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.12/dist-packages (from simple-parsing<0.2.0,>=0.1.6->sae-lens) (0.17.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer-lens) (3.4.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.38.1->sae-lens) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer-lens) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer-lens) (4.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer-lens) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer-lens) (2.11.7)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer-lens) (2.37.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (3.12.15)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=0.23.0->transformer-lens) (1.1.9)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer-lens) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.13.5->transformer-lens) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.13.5->transformer-lens) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.13.5->transformer-lens) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->transformer-lens) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.1.0->sae-lens) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.1.0->sae-lens) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.1.0->sae-lens) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.1.0->sae-lens) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.6->transformer-lens) (1.3.0)
# Requirement already satisfied: dol in /usr/local/lib/python3.12/dist-packages (from graze->babe<0.0.8,>=0.0.7->sae-lens) (0.3.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.6->transformer-lens) (3.0.2)
# Requirement already satisfied: config2py in /usr/local/lib/python3.12/dist-packages (from py2store->babe<0.0.8,>=0.0.7->sae-lens) (0.1.38)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from py2store->babe<0.0.8,>=0.0.7->sae-lens) (6.5.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (1.20.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens) (5.0.2)
# Requirement already satisfied: i2 in /usr/local/lib/python3.12/dist-packages (from config2py->py2store->babe<0.0.8,>=0.0.7->sae-lens) (0.1.48)

# %%
import torch
import os

from sae_lens import (
    LanguageModelSAERunnerConfig,
    SAETrainingRunner,
    StandardTrainingSAEConfig,
    LoggingConfig,
)

if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"

print("Using device:", device)
os.environ["TOKENIZERS_PARALLELISM"] = "false"
# Out:
# Using device: cuda

# %% [markdown]
# # Model Selection and Evaluation (Feel Free to Skip)
#
# We'll use the runner to train an SAE on a TinyStories Model. This is a very small model so we can train an SAE on it quite quickly. Before we get started, let's load in the model with `transformer_lens` and see what it can do.
#
# TransformerLens gives us 2 functions that are useful here (and circuits viz provides a third):
#
# 1. `transformer_lens.utils.test_prompt` will help us see when the model can infer one token.
# 2. `HookedTransformer.generate` will help us see what happens when we sample from the model.
# 3. `circuitsvis.logits.token_log_probs` will help us visualize the log probs of tokens at several positions in a prompt.

# %%
from transformer_lens import HookedTransformer

model = HookedTransformer.from_pretrained(
    "tiny-stories-1L-21M"
)  # This will wrap huggingface models and has lots of nice utilities.
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/269M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/722 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/269M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# Loaded pretrained model tiny-stories-1L-21M into HookedTransformer

# %% [markdown]
# ### Getting a vibe for a model using `model.generate`

# %% [markdown]
# Let's start by generating some stories using the model.

# %%
# here we use generate to get 10 completeions with temperature 1. Feel free to play with the prompt to make it more interesting.
for i in range(5):
    display(
        model.generate(
            "Once upon a time",
            stop_at_eos=False,  # avoids a bug on MPS
            temperature=1,
            verbose=False,
            max_new_tokens=50,
        )
    )
# Out:
# 'Once upon a time, there was a swamp. The swamp looked dark and mysterious. Nearby, there was a big tree. \n\nOne day, a family asked their three of them "What is this?" \nAn elderly brother comes to deliver a story'
# "Once upon a time, there was a green animal called Mixy. She was very shy. He was on the other side of the forest and didn't move. \n\nOne day, the other animals were playing in the park. They were having lots of fun"
# 'Once upon a time, there lived a distant yacht. The yacht sailed far away. The yacht was far away, far. But the yacht was strong, and it could not go far.\n\nOne day, the yacht sailed out of the sea. It was a'
# 'Once upon a time, there was a stone. This magical stones could make special wishes come true. Everyone loved the stone and value it gave the thankful pearl from the harsh sunshine. \n\nThe End.\n\nRandom sentence: He was so strong that he'
# 'Once upon a time there was a dependable car. It was red and shiny and new. One day, the car decided to go on an adventure. It drove through the countryside until it came to a big icy mountain. The mountain was very steep and the car was'

# %% [markdown]
# One thing we notice is that the model seems to be able to repeat the name of the main character very consistently. It can output a pronoun intead but in some stories will repeat the protagonists name. This seems like an interesting capability to analyse with SAEs. To better understand the models ability to remember the protagonists name, let's extract a prompt where the next character is determined and use the "test_prompt" utility from TransformerLens to check the ranking of the token for that name.

# %% [markdown]
# ### Spot checking model abilities with `transformer_lens.utils.test_prompt`

# %%
from transformer_lens.utils import test_prompt

# Test the model with a prompt
test_prompt(
    "Once upon a time, there was a little girl named Lily. She lived in a big, happy little town. On her big adventure,",
    " Lily",
    model,
    prepend_space_to_answer=False,
)

# %% [markdown]
# In the output above, we see that the model assigns ~ 70% probability to "she" being the next token, and a 13% chance to " Lily" being the next token. Other names like Lucy or Anna are not highly ranked.

# %% [markdown]
# ### Exploring Model Capabilities with Log Probs

# %% [markdown]
# Looking at token ranking for a single prompt is interesting, but a much higher through way to understand models is to look at token log probs for all tokens in text. We can use the `circuits_vis` package to get a nice visualization where we can see tokenization, and hover to get the top5 tokens by log probability. Darker tokens are tokens where the model assigned a higher probability to the actual next token.

# %%
import circuitsvis as cv  # optional dep, install with pip install circuitsvis

# Let's make a longer prompt and see the log probabilities of the tokens
example_prompt = """Hi, how are you doing this? I'm really enjoying your posts"""
logits, cache = model.run_with_cache(example_prompt)
cv.logits.token_log_probs(
    model.to_tokens(example_prompt),
    model(example_prompt)[0].log_softmax(dim=-1),
    model.to_string,
)
# hover on the output to see the result.

# %% [markdown]
# Let's combine `model.generate` and the token log probs visualization to see the log probs on text generated by the model. Note that we can play with the temperature and this should sample less likely trajectories according to the model. I've increased the maximum number of tokens in order to get a full story.
#
# Some things to explore:
#
# - Which tokens does the model assign high probability to? Can you see how the model should know which word comes next?
# - What happens if you increase / decrease the temperature?
# - Do the rankings of tokens seem sensible to you? What about where the model doesn't assign a high probability to the token which came next?

# %%
example_prompt = model.generate(
    "Once upon a time",
    stop_at_eos=False,  # avoids a bug on MPS
    temperature=1,
    verbose=True,
    max_new_tokens=200,
)
logits, cache = model.run_with_cache(example_prompt)
cv.logits.token_log_probs(
    model.to_tokens(example_prompt),
    model(example_prompt)[0].log_softmax(dim=-1),
    model.to_string,
)

# %% [markdown]
# # Training an SAE
#
# Now we're ready to train out SAE. We'll make a runner config, instantiate the runner and the rest is taken care of for us!
#
# During training, you use weights and biases to check key metrics which indicate how well we are able to optimize the variables we care about.
#
# To get a better sense of which variables to look at, you can read my (Joseph's) post [here](https://www.lesswrong.com/posts/f9EgfLSurAiqRJySD/open-source-sparse-autoencoders-for-all-residual-stream) and especially look at my weights and biases report [here](https://links-cdn.wandb.ai/wandb-public-images/links/jbloom/uue9i416.html).
#
# A few tips:
#
# - Feel free to reorganize your wandb dashboard to put L0, CE_Loss_score, explained variance and other key metrics in one section at the top.
# - Make a [run comparer](https://docs.wandb.ai/guides/app/features/panels/run-comparer) when tuning hyperparameters.
# - You can download the resulting sparse autoencoder / sparsity estimate from wandb and upload them to huggingface if you want to share your SAE with other.
#   - cfg.json (training config)
#   - sae_weight.safetensors (model weights)
#   - sparsity.safetensors (sparsity estimate)

# %% [markdown]
# ## MLP Out
#
# I've tuned the hyperparameters below for a decent SAE which achieves 86% CE Loss recovered and an L0 of ~85, and runs in about 2 hours on an M3 Max. You can get an SAE that looks better faster if you only consider L0 and CE loss but it will likely have more dense features and more dead features. Here's a link to my output with two runs with two different L1's: https://wandb.ai/jbloom/sae_lens_tutorial .

# %%
total_training_steps = 30_000  # probably we should do more
# batch_size = 4096
batch_size = 1024
total_training_tokens = total_training_steps * batch_size

lr_warm_up_steps = 0
lr_decay_steps = total_training_steps // 5  # 20% of training
l1_warm_up_steps = total_training_steps // 20  # 5% of training

cfg = LanguageModelSAERunnerConfig(
    # Data Generating Function (Model + Training Distibuion)
    # model_name="tiny-stories-1L-21M",  # our model (more options here: https://neelnanda-io.github.io/TransformerLens/generated/model_properties_table.html)
    # model_name="Qwen/Qwen2.5-1.5B",  # our model (more options here: https://neelnanda-io.github.io/TransformerLens/generated/model_properties_table.html)
    # hook_name="model.layers.0.mlp.down_proj",
    model_name="Qwen/Qwen3-4B",
    # hook_name="model.layers.16.mlp.down_proj",
    hook_name="blocks.16.hook_mlp_out",
    # hook_name="blocks.0.hook_mlp_out",  # A valid hook point (see more details here: https://neelnanda-io.github.io/TransformerLens/generated/demos/Main_Demo.html#Hook-Points)
    dataset_path="hippotoday/sae-train-data",  # this is a tokenized language dataset on Huggingface for the Tiny Stories corpus.
    is_dataset_tokenized=False,
    # trust_remote_code=False,
    streaming=False,  # we could pre-download the token dataset if it was small.
    # SAE Parameters
    sae=StandardTrainingSAEConfig(
        # d_in=1024,  # the width of the mlp output.
        # d_in=1536,
        d_in=2560,
        d_sae=16384,  # the width of the SAE. Larger will result in better stats but slower training.
        apply_b_dec_to_input=False,  # We won't apply the decoder weights to the input.
        normalize_activations="expected_average_only_in",
        l1_coefficient=5,  # will control how sparse the feature activations are
        l1_warm_up_steps=l1_warm_up_steps,  # this can help avoid too many dead features initially.
    ),
    # Training Parameters
    lr=5e-5,  # lower the better, we'll go fairly high to speed up the tutorial.
    adam_beta1=0.9,  # adam params (default, but once upon a time we experimented with these.)
    adam_beta2=0.999,
    lr_scheduler_name="constant",  # constant learning rate with warmup. Could be better schedules out there.
    lr_warm_up_steps=lr_warm_up_steps,  # this can help avoid too many dead features initially.
    lr_decay_steps=lr_decay_steps,  # this will help us avoid overfitting.
    train_batch_size_tokens=batch_size,
    context_size=512,  # will control the lenght of the prompts we feed to the model. Larger is better but slower. so for the tutorial we'll use a short one.
    # Activation Store Parameters
    n_batches_in_buffer=32,  # controls how many activations we store / shuffle.
    training_tokens=total_training_tokens,  # 100 million tokens is quite a few, but we want to see good stats. Get a coffee, come back.
    store_batch_size_prompts=16,
    # Resampling protocol
    feature_sampling_window=1000,  # this controls our reporting of feature sparsity stats
    dead_feature_window=1000,  # would effect resampling or ghost grads if we were using it.
    dead_feature_threshold=1e-4,  # would effect resampling or ghost grads if we were using it.
    # WANDB
    logger=LoggingConfig(
        log_to_wandb=True,  # always use wandb unless you are just testing code.
        wandb_project="sae_lens_tutorial",
        wandb_log_frequency=30,
        eval_every_n_wandb_logs=20,
    ),
    # Misc
    device=device,
    seed=42,
    n_checkpoints=0,
    checkpoint_path="checkpoints",
    dtype="float32",
)
# look at the next cell to see some instruction for what to do while this is running.
sparse_autoencoder = SAETrainingRunner(cfg).run()
# Out:
# /tmp/ipython-input-2580866550.py:66: DeprecationWarning: Use LanguageModelSAETrainingRunner instead
#   sparse_autoencoder = SAETrainingRunner(cfg).run()
# WARNING:root:Loading model Qwen/Qwen3-4B requires setting trust_remote_code=True
# WARNING:root:Loading model Qwen/Qwen3-4B state dict requires setting trust_remote_code=True
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# `trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'hippotoday/sae-train-data' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# ERROR:datasets.load:`trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'hippotoday/sae-train-data' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# Loaded pretrained model Qwen/Qwen3-4B into HookedTransformer
# /usr/local/lib/python3.12/dist-packages/sae_lens/training/activations_store.py:317: UserWarning: Dataset is not tokenized. Pre-tokenizing will improve performance and allows for more control over special tokens. See https://jbloomaus.github.io/SAELens/training_saes/#pretokenizing-datasets for more info.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sae_lens/saes/sae.py:249: UserWarning:
# This SAE has non-empty model_from_pretrained_kwargs.
# For optimal performance, load the model like so:
# model = HookedSAETransformer.from_pretrained_no_processing(..., **cfg.model_from_pretrained_kwargs)
#   warnings.warn(
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">standard-16384-LR-5e-05-Tokens-3.072e+07</strong> at: <a href='https://wandb.ai/wenjiehuhippo-university-of-wisconsin-madison/sae_lens_tutorial/runs/yu02e3kn' target="_blank">https://wandb.ai/wenjiehuhippo-university-of-wisconsin-madison/sae_lens_tutorial/runs/yu02e3kn</a><br> View project at: <a href='https://wandb.ai/wenjiehuhippo-university-of-wisconsin-madison/sae_lens_tutorial' target="_blank">https://wandb.ai/wenjiehuhippo-university-of-wisconsin-madison/sae_lens_tutorial</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250919_202703-yu02e3kn/logs</code>
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/content/wandb/run-20250919_202817-yf0h7410</code>
# Syncing run <strong><a href='https://wandb.ai/wenjiehuhippo-university-of-wisconsin-madison/sae_lens_tutorial/runs/yf0h7410' target="_blank">standard-16384-LR-5e-05-Tokens-3.072e+07</a></strong> to <a href='https://wandb.ai/wenjiehuhippo-university-of-wisconsin-madison/sae_lens_tutorial' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/wenjiehuhippo-university-of-wisconsin-madison/sae_lens_tutorial' target="_blank">https://wandb.ai/wenjiehuhippo-university-of-wisconsin-madison/sae_lens_tutorial</a>
#  View run at <a href='https://wandb.ai/wenjiehuhippo-university-of-wisconsin-madison/sae_lens_tutorial/runs/yf0h7410' target="_blank">https://wandb.ai/wenjiehuhippo-university-of-wisconsin-madison/sae_lens_tutorial/runs/yf0h7410</a>
# Training SAE:   0%|          | 0/30720000 [00:00<?, ?it/s]
# Estimating norm scaling factor:   0%|          | 0/1000 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.84s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.83s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.83s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.90s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.83s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.86s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.84s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.86s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.83s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.83s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:10,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:30,  2.01s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.92s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.88s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.86s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.86s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.85s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.83s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.85s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.84s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.84s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.94s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.87s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
#                                                                  /usr/local/lib/python3.12/dist-packages/sae_lens/training/activations_store.py:687: UserWarning: All samples in the training dataset have been exhausted, beginning new epoch.
#   warnings.warn(
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.86s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.83s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:27,  1.80s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.82s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:23,  1.83s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:10<00:18,  1.83s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.83s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.83s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.83s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.86s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.85s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.84s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.08s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.94s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.87s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.86s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.85s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.83s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.85s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.84s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.84s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.94s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.87s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
#                                                                  /usr/local/lib/python3.12/dist-packages/sae_lens/training/activations_store.py:687: UserWarning: All samples in the training dataset have been exhausted, beginning new epoch.
#   warnings.warn(
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.88s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.86s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.84s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.90s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.85s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:26<00:03,  1.85s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.86s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.84s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:27,  1.86s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.85s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:23,  1.84s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.85s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.85s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.83s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.83s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.83s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.85s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.86s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.84s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.84s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.85s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:26<00:03,  1.85s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.84s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.12s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.96s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.90s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.87s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:15<00:14,  1.85s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.85s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:26<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.84s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.84s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.94s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.87s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
#                                                                  /usr/local/lib/python3.12/dist-packages/sae_lens/training/activations_store.py:687: UserWarning: All samples in the training dataset have been exhausted, beginning new epoch.
#   warnings.warn(
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.86s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.92s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.87s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.85s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.85s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.83s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.83s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.83s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.83s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.86s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.83s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:10,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.83s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.90s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.13s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.96s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.90s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.87s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.86s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:15<00:14,  1.85s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.85s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:26<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.84s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:29,  1.99s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.90s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.87s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.86s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.86s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
#                                                                  /usr/local/lib/python3.12/dist-packages/sae_lens/training/activations_store.py:687: UserWarning: All samples in the training dataset have been exhausted, beginning new epoch.
#   warnings.warn(
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.83s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.90s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.86s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.84s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.85s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.86s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.85s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.85s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:27,  1.82s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.83s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:23,  1.83s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:21,  1.83s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.83s/it]
#
# ...
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.93s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.87s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.85s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.85s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.83s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:10,  1.83s/it]
#
#                                                                  /usr/local/lib/python3.12/dist-packages/sae_lens/training/activations_store.py:687: UserWarning: All samples in the training dataset have been exhausted, beginning new epoch.
#   warnings.warn(
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.83s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.88s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.85s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.83s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:30,  2.01s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.91s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.88s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.86s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.86s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.85s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.83s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.85s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.84s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.84s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.84s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.94s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.87s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.87s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.85s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
#                                                                  /usr/local/lib/python3.12/dist-packages/sae_lens/training/activations_store.py:687: UserWarning: All samples in the training dataset have been exhausted, beginning new epoch.
#   warnings.warn(
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.86s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:02<00:31,  2.10s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:27,  1.95s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.89s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.88s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.86s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:13<00:16,  1.85s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.84s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:24<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.84s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:26,  1.86s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:24,  1.85s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:11<00:18,  1.84s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.84s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.85s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.83s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:22<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.84s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.83s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
# Refilling buffer: 100%|██████████| 16/16 [00:29<00:00,  1.85s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Refilling buffer:   6%|▋         | 1/16 [00:01<00:27,  1.80s/it]
#
# Refilling buffer:  12%|█▎        | 2/16 [00:03<00:25,  1.82s/it]
#
# Refilling buffer:  19%|█▉        | 3/16 [00:05<00:23,  1.83s/it]
#
# Refilling buffer:  25%|██▌       | 4/16 [00:07<00:22,  1.84s/it]
#
# Refilling buffer:  31%|███▏      | 5/16 [00:09<00:20,  1.84s/it]
#
# Refilling buffer:  38%|███▊      | 6/16 [00:10<00:18,  1.83s/it]
#
# Refilling buffer:  44%|████▍     | 7/16 [00:12<00:16,  1.84s/it]
#
# Refilling buffer:  50%|█████     | 8/16 [00:14<00:14,  1.83s/it]
#
# Refilling buffer:  56%|█████▋    | 9/16 [00:16<00:12,  1.83s/it]
#
# Refilling buffer:  62%|██████▎   | 10/16 [00:18<00:11,  1.84s/it]
#
# Refilling buffer:  69%|██████▉   | 11/16 [00:20<00:09,  1.83s/it]
#
# Refilling buffer:  75%|███████▌  | 12/16 [00:21<00:07,  1.83s/it]
#
# Refilling buffer:  81%|████████▏ | 13/16 [00:23<00:05,  1.83s/it]
#
# Refilling buffer:  88%|████████▊ | 14/16 [00:25<00:03,  1.84s/it]
#
# Refilling buffer:  94%|█████████▍| 15/16 [00:27<00:01,  1.83s/it]
#
#
#
# Refilling buffer:   0%|          | 0/16 [00:00<?, ?it/s]

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# # TO DO: Understanding TinyStories-1L with our SAE
#
# I haven't had time yet to complete this section, but I'd love to see a PR where someones uses an SAE they trained in this tutorial to understand this model better.

# %%
import pandas as pd

# Let's start by getting the top 10 logits for each feature
projection_onto_unembed = sparse_autoencoder.W_dec @ model.W_U


# get the top 10 logits.
vals, inds = torch.topk(projection_onto_unembed, 10, dim=1)

# get 10 random features
random_indices = torch.randint(0, projection_onto_unembed.shape[0], (10,))

# Show the top 10 logits promoted by those features
top_10_logits_df = pd.DataFrame(
    [model.to_str_tokens(i) for i in inds[random_indices]],
    index=random_indices.tolist(),
).T
top_10_logits_df
